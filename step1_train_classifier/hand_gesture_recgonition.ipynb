# %%
# Tạo folder data để các bạn upload file 3 file data được tạo ra ở step 0 vào folder data
# Các bạn upload file hand_gesture.yaml ngoài folder data
#!mkdir data

# %%
# Nếu đã chạy thành công step 0 thì các bạn không chạy cell này và chỉ upload 3 file data của các bạn vào thư mục data
# Và upload file hand_gesture.yaml bên ngoài thư mục data
# Nếu không chạy được ở step 0 thì các bạn run cell này để download data
#!gdown  1gzWOtABiVmJ38usCSDe5F9gR2tECt3zu -O data/
#!gdown  15lwipssmC_K82ukRfb0uVCiDH1TZ3QCf -O data/
#!gdown  1nIo1_wBmkovz-u_BCsV5c1Kbz6ZqoKwq -O data/
# Download file hand_gesture.yam
#!gdown  1ZteHYSgbuZu_GcUJHW8ZzoZv1DE8-oLw

# %%
#!pip install mediapipe==0.10.18

# %%
#!pip install torchmetrics

# %%
import os
import cv2
import yaml
import torch
import numpy as np
import pandas as pd
from  torch import nn
import mediapipe as mp
from torch import optim
from datetime import datetime
from torchmetrics import Accuracy
from torch.utils.data import Dataset

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        list_label = label_dict_from_config_file("hand_gesture.yaml")

        self.linear_relu_stack = nn.Sequential(
            # First hidden layer with ReLU and BatchNorm1d
            nn.Linear(63, 128),
            nn.ReLU(),
            nn.BatchNorm1d(128),

            # Second hidden layer with ReLU and Dropout
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Dropout(0.4),

            # Third hidden layer with ReLU and Dropout
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Dropout(0.4),

            # Fourth hidden layer with ReLU and Dropout
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Dropout(0.6),

            # Output layer for classification
            nn.Linear(128, len(list_label))
            )
    def forward(self, x):
        # Flatten the input
        x = self.flatten(x)
        # Pass through the linear_relu_stack
        logits = self.linear_relu_stack(x)
        return logits

    def predict(self,x,threshold=0.8):
        logits = self(x)
        softmax_prob = nn.Softmax(dim=1)(logits)
        chosen_ind = torch.argmax(softmax_prob,dim=1)
        return torch.where(softmax_prob[0,chosen_ind]>threshold,chosen_ind,-1)

    def predict_with_known_class(self,x):
        logits = self(x)
        softmax_prob = nn.Softmax(dim=1)(logits)
        return torch.argmax(softmax_prob,dim=1)

    def score(self,logits):
        return -torch.amax(logits,dim=1)

# %%
def label_dict_from_config_file(relative_path):
    with open(relative_path,"r") as f:
       label_tag = yaml.full_load(f)["gestures"]
    return label_tag

# %%
class HandLandmarksDetector():
    def __init__(self) -> None:
        self.mp_drawing = mp.solutions.drawing_utils
        self.mp_drawing_styles = mp.solutions.drawing_styles
        self.mp_hands = mp.solutions.hands
        self.detector = self.mp_hands.Hands(False,max_num_hands=1,min_detection_confidence=0.5)

    def detectHand(self,frame):
        hands = []
        frame = cv2.flip(frame, 1)
        annotated_image = frame.copy()
        results = self.detector.process(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
        if results.multi_hand_landmarks is not None:
            for hand_landmarks in results.multi_hand_landmarks:
                hand = []
                self.mp_drawing.draw_landmarks(
                    annotated_image,
                    hand_landmarks,
                    self.mp_hands.HAND_CONNECTIONS,
                    self.mp_drawing_styles.get_default_hand_landmarks_style(),
                    self.mp_drawing_styles.get_default_hand_connections_style())
                for landmark in hand_landmarks.landmark:
                    x,y,z = landmark.x,landmark.y,landmark.z
                    hand.extend([x,y,z])
            hands.append(hand)
        return hands,annotated_image

# %%
class CustomImageDataset(Dataset):
    def __init__(self, data_file):
        self.data = pd.read_csv(data_file)
        self.labels = torch.from_numpy(self.data.iloc[:,0].to_numpy())

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        one_hot_label = self.labels[idx]
        torch_data = torch.from_numpy(self.data.iloc[idx,1:].to_numpy(dtype=np.float32))
        return torch_data, one_hot_label

# %%
class EarlyStopper:
    def __init__(self, patience=1, min_delta=0):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.watched_metrics = np.inf

    def early_stop(self, current_value):
        if current_value < self.watched_metrics:
            self.watched_metrics = current_value
            self.counter = 0
        elif current_value > (self.watched_metrics + self.min_delta):
            self.counter += 1
            if self.counter >= self.patience:
                return True
        return False

# %%
def train(trainloader, val_loader, model, loss_function, early_stopper, optimizer):
    # add auroc score
    best_vloss = 1_000_000
    timestamp = datetime.now().strftime('%d-%m %H:%M')
    for epoch in range(300):
        #training step
        model.train(True)
        running_loss = 0.0
        acc_train = Accuracy(num_classes=len(LIST_LABEL), task='MULTICLASS')
        for batch_number,data in enumerate(trainloader):
            inputs,labels = data

            optimizer.zero_grad()
            preds = model(inputs)

            loss = loss_function(preds, labels)
            loss.backward()
            optimizer.step()


            acc_train.update(model.predict_with_known_class(inputs), labels)
            running_loss += loss.item()
        avg_loss = running_loss / len(trainloader)
        # validating step
        model.train(False)
        running_vloss = 0.0
        acc_val = Accuracy(num_classes=len(LIST_LABEL), task='MULTICLASS')
        for i, vdata in enumerate(val_loader):
            vinputs, vlabels = vdata
            preds = model(vinputs)
            vloss = loss_function(preds, vlabels)
            running_vloss += vloss.item()
            acc_val.update(model.predict_with_known_class(vinputs), vlabels)

        # Log the running loss averaged per batch
        # for both training and validation
        print(f"Epoch {epoch}: ")
        print(f"Accuracy train:{acc_train.compute().item()}, val:{acc_val.compute().item()}")
        avg_vloss = running_vloss / len(val_loader)
        print('LOSS train {} valid {}'.format(avg_loss, avg_vloss))
        print('Training vs. Validation Loss',
                        { 'Training' : avg_loss, 'Validation' : avg_vloss },
                        epoch + 1)
        print('Training vs. Validation accuracy',
                        { 'Training' : acc_train.compute().item()
                        , 'Validation' : acc_val.compute().item() },
                        epoch + 1)

        # Track best performance, and save the model's state
        if avg_vloss < best_vloss:
            best_vloss = avg_vloss
            best_model_path = f'./{save_path}/model_{timestamp}_{model.__class__.__name__}_best'
            torch.save(model.state_dict(), best_model_path)

        if early_stopper.early_stop(avg_vloss):

            print(f"stopping at epoch {epoch}, minimum: {early_stopper.watched_metrics}")
            break


    model_path = f'./{save_path}/model_{timestamp}_{model.__class__.__name__}_last'
    torch.save(model.state_dict(), model_path)

    print(acc_val.compute())
    return model, best_model_path

# %%
DATA_FOLDER_PATH="./data/"
LIST_LABEL = label_dict_from_config_file("hand_gesture.yaml")
train_path = os.path.join(DATA_FOLDER_PATH,"landmark_train.csv")
val_path = os.path.join(DATA_FOLDER_PATH,"landmark_val.csv")
save_path = './models'
os.makedirs(save_path,exist_ok=True)

trainset = CustomImageDataset(train_path)

trainloader = torch.utils.data.DataLoader(trainset, batch_size=40, shuffle=True)

valset = CustomImageDataset(os.path.join(val_path))
val_loader = torch.utils.data.DataLoader(valset,batch_size=50, shuffle=False)


model = NeuralNetwork()
loss_function = nn.CrossEntropyLoss()
early_stopper = EarlyStopper(patience=30, min_delta=0.01)

optimizer = optim.Adam(model.parameters(), lr=0.0001)



model, best_model_path = train(trainloader, val_loader, model, loss_function, early_stopper, optimizer)
# Out:
# Epoch 0:
# Accuracy train:0.22669284045696259, val:0.41296929121017456
# LOSS train 1.6083846917519202 valid 1.6064776380856831
# Training vs. Validation Loss {'Training': 1.6083846917519202, 'Validation': 1.6064776380856831} 1
# Training vs. Validation accuracy {'Training': 0.22669284045696259, 'Validation': 0.41296929121017456} 1
# Epoch 1:
# Accuracy train:0.30323848128318787, val:0.5221843123435974
# LOSS train 1.5885615394665644 valid 1.5835602084795635
# Training vs. Validation Loss {'Training': 1.5885615394665644, 'Validation': 1.5835602084795635} 2
# Training vs. Validation accuracy {'Training': 0.30323848128318787, 'Validation': 0.5221843123435974} 2
# Epoch 2:
# Accuracy train:0.4131501615047455, val:0.457337886095047
# LOSS train 1.5588048513119037 valid 1.5620547731717427
# Training vs. Validation Loss {'Training': 1.5588048513119037, 'Validation': 1.5620547731717427} 3
# Training vs. Validation accuracy {'Training': 0.4131501615047455, 'Validation': 0.457337886095047} 3
# Epoch 3:
# Accuracy train:0.47399410605430603, val:0.49146756529808044
# LOSS train 1.5267430268801176 valid 1.5284459590911865
# Training vs. Validation Loss {'Training': 1.5267430268801176, 'Validation': 1.5284459590911865} 4
# Training vs. Validation accuracy {'Training': 0.47399410605430603, 'Validation': 0.49146756529808044} 4
# Epoch 4:
# Accuracy train:0.5073601603507996, val:0.49146756529808044
# LOSS train 1.4717483107860272 valid 1.4692660570144653
# Training vs. Validation Loss {'Training': 1.4717483107860272, 'Validation': 1.4692660570144653} 5
# Training vs. Validation accuracy {'Training': 0.5073601603507996, 'Validation': 0.49146756529808044} 5
# Epoch 5:
# Accuracy train:0.5574092268943787, val:0.4948805570602417
# LOSS train 1.3876030949445872 valid 1.382914384206136
# Training vs. Validation Loss {'Training': 1.3876030949445872, 'Validation': 1.382914384206136} 6
# Training vs. Validation accuracy {'Training': 0.5574092268943787, 'Validation': 0.4948805570602417} 6
# Epoch 6:
# Accuracy train:0.570166826248169, val:0.4846416413784027
# LOSS train 1.2488887722675617 valid 1.2576967179775238
# Training vs. Validation Loss {'Training': 1.2488887722675617, 'Validation': 1.2576967179775238} 7
# Training vs. Validation accuracy {'Training': 0.570166826248169, 'Validation': 0.4846416413784027} 7
# Epoch 7:
# Accuracy train:0.6064769625663757, val:0.5665528774261475
# LOSS train 1.1076731062852418 valid 1.0989557007948558
# Training vs. Validation Loss {'Training': 1.1076731062852418, 'Validation': 1.0989557007948558} 8
# Training vs. Validation accuracy {'Training': 0.6064769625663757, 'Validation': 0.5665528774261475} 8
# Epoch 8:
# Accuracy train:0.6486751437187195, val:0.61774742603302
# LOSS train 0.9631513884434333 valid 0.9358870685100555
# Training vs. Validation Loss {'Training': 0.9631513884434333, 'Validation': 0.9358870685100555} 9
# Training vs. Validation accuracy {'Training': 0.6486751437187195, 'Validation': 0.61774742603302} 9
# Epoch 9:
# Accuracy train:0.725220799446106, val:0.6552901268005371
# LOSS train 0.8144379602028773 valid 0.7972605377435684
# Training vs. Validation Loss {'Training': 0.8144379602028773, 'Validation': 0.7972605377435684} 10
# Training vs. Validation accuracy {'Training': 0.725220799446106, 'Validation': 0.6552901268005371} 10
# Epoch 10:
# Accuracy train:0.7752698659896851, val:0.6791808605194092
# LOSS train 0.7008649477591882 valid 0.6610298305749893
# Training vs. Validation Loss {'Training': 0.7008649477591882, 'Validation': 0.6610298305749893} 11
# Training vs. Validation accuracy {'Training': 0.7752698659896851, 'Validation': 0.6791808605194092} 11
# Epoch 11:
# Accuracy train:0.8155053853988647, val:0.7303754091262817
# LOSS train 0.599723206116603 valid 0.5408078792194525
# Training vs. Validation Loss {'Training': 0.599723206116603, 'Validation': 0.5408078792194525} 12
# Training vs. Validation accuracy {'Training': 0.8155053853988647, 'Validation': 0.7303754091262817} 12
# Epoch 12:
# Accuracy train:0.8645731210708618, val:0.7781569957733154
# LOSS train 0.494298789363641 valid 0.43244848897059757
# Training vs. Validation Loss {'Training': 0.494298789363641, 'Validation': 0.43244848897059757} 13
# Training vs. Validation accuracy {'Training': 0.8645731210708618, 'Validation': 0.7781569957733154} 13
# Epoch 13:
# Accuracy train:0.915603518486023, val:0.8976109027862549
# LOSS train 0.39496898364562255 valid 0.3279038282732169
# Training vs. Validation Loss {'Training': 0.39496898364562255, 'Validation': 0.3279038282732169} 14
# Training vs. Validation accuracy {'Training': 0.915603518486023, 'Validation': 0.8976109027862549} 14
# Epoch 14:
# Accuracy train:0.9205102920532227, val:0.979522168636322
# LOSS train 0.33713064457361513 valid 0.24170944187790155
# Training vs. Validation Loss {'Training': 0.33713064457361513, 'Validation': 0.24170944187790155} 15
# Training vs. Validation accuracy {'Training': 0.9205102920532227, 'Validation': 0.979522168636322} 15
# Epoch 15:
# Accuracy train:0.9450441598892212, val:0.9931740760803223
# LOSS train 0.2652872485610155 valid 0.17253099288791418
# Training vs. Validation Loss {'Training': 0.2652872485610155, 'Validation': 0.17253099288791418} 16
# Training vs. Validation accuracy {'Training': 0.9450441598892212, 'Validation': 0.9931740760803223} 16
# Epoch 16:
# Accuracy train:0.9558390378952026, val:0.9931740760803223
# LOSS train 0.23320393722790939 valid 0.11712534679099917
# Training vs. Validation Loss {'Training': 0.23320393722790939, 'Validation': 0.11712534679099917} 17
# Training vs. Validation accuracy {'Training': 0.9558390378952026, 'Validation': 0.9931740760803223} 17
# Epoch 17:
# Accuracy train:0.96467125415802, val:0.9931740760803223
# LOSS train 0.1927490927852117 valid 0.07403593269797663
# Training vs. Validation Loss {'Training': 0.1927490927852117, 'Validation': 0.07403593269797663} 18
# Training vs. Validation accuracy {'Training': 0.96467125415802, 'Validation': 0.9931740760803223} 18
# Epoch 18:
# Accuracy train:0.9784101843833923, val:0.9931740760803223
# LOSS train 0.1635607799085287 valid 0.046410703333094716
# Training vs. Validation Loss {'Training': 0.1635607799085287, 'Validation': 0.046410703333094716} 19
# Training vs. Validation accuracy {'Training': 0.9784101843833923, 'Validation': 0.9931740760803223} 19
# Epoch 19:
# Accuracy train:0.9705593585968018, val:0.9931740760803223
# LOSS train 0.1472654978816326 valid 0.04578512045554817
# Training vs. Validation Loss {'Training': 0.1472654978816326, 'Validation': 0.04578512045554817} 20
# Training vs. Validation accuracy {'Training': 0.9705593585968018, 'Validation': 0.9931740760803223} 20
# Epoch 20:
# Accuracy train:0.9784101843833923, val:0.9931740760803223
# LOSS train 0.11064721242739604 valid 0.035478375386446714
# Training vs. Validation Loss {'Training': 0.11064721242739604, 'Validation': 0.035478375386446714} 21
# Training vs. Validation accuracy {'Training': 0.9784101843833923, 'Validation': 0.9931740760803223} 21
# Epoch 21:
# Accuracy train:0.9793915748596191, val:0.9931740760803223
# LOSS train 0.11128937667952134 valid 0.031218700809404254
# Training vs. Validation Loss {'Training': 0.11128937667952134, 'Validation': 0.031218700809404254} 22
# Training vs. Validation accuracy {'Training': 0.9793915748596191, 'Validation': 0.9931740760803223} 22
# Epoch 22:
# Accuracy train:0.9774288535118103, val:0.9931740760803223
# LOSS train 0.11162452328090484 valid 0.027618841151706874
# Training vs. Validation Loss {'Training': 0.11162452328090484, 'Validation': 0.027618841151706874} 23
# Training vs. Validation accuracy {'Training': 0.9774288535118103, 'Validation': 0.9931740760803223} 23
# Epoch 23:
# Accuracy train:0.9735034108161926, val:0.9931740760803223
# LOSS train 0.09902421585642375 valid 0.020426401072957862
# Training vs. Validation Loss {'Training': 0.09902421585642375, 'Validation': 0.020426401072957862} 24
# Training vs. Validation accuracy {'Training': 0.9735034108161926, 'Validation': 0.9931740760803223} 24
# Epoch 24:
# Accuracy train:0.9862610697746277, val:0.9931740760803223
# LOSS train 0.0942486639206226 valid 0.018730113884278882
# Training vs. Validation Loss {'Training': 0.0942486639206226, 'Validation': 0.018730113884278882} 25
# Training vs. Validation accuracy {'Training': 0.9862610697746277, 'Validation': 0.9931740760803223} 25
# Epoch 25:
# Accuracy train:0.9901864528656006, val:0.9931740760803223
# LOSS train 0.07755669263693002 valid 0.02146622526925057
# Training vs. Validation Loss {'Training': 0.07755669263693002, 'Validation': 0.02146622526925057} 26
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9931740760803223} 26
# Epoch 26:
# Accuracy train:0.983316957950592, val:0.9931740760803223
# LOSS train 0.10027956253347489 valid 0.02061656233854592
# Training vs. Validation Loss {'Training': 0.10027956253347489, 'Validation': 0.02061656233854592} 27
# Training vs. Validation accuracy {'Training': 0.983316957950592, 'Validation': 0.9931740760803223} 27
# Epoch 27:
# Accuracy train:0.981354296207428, val:0.9931740760803223
# LOSS train 0.07676705517447911 valid 0.018493509259618197
# Training vs. Validation Loss {'Training': 0.07676705517447911, 'Validation': 0.018493509259618197} 28
# Training vs. Validation accuracy {'Training': 0.981354296207428, 'Validation': 0.9931740760803223} 28
# Epoch 28:
# Accuracy train:0.9882237315177917, val:0.9931740760803223
# LOSS train 0.07003108311731082 valid 0.022294917497977924
# Training vs. Validation Loss {'Training': 0.07003108311731082, 'Validation': 0.022294917497977924} 29
# Training vs. Validation accuracy {'Training': 0.9882237315177917, 'Validation': 0.9931740760803223} 29
# Epoch 29:
# Accuracy train:0.9852796792984009, val:0.9931740760803223
# LOSS train 0.07426064139088759 valid 0.018374309584032744
# Training vs. Validation Loss {'Training': 0.07426064139088759, 'Validation': 0.018374309584032744} 30
# Training vs. Validation accuracy {'Training': 0.9852796792984009, 'Validation': 0.9931740760803223} 30
# Epoch 30:
# Accuracy train:0.9872424006462097, val:0.9931740760803223
# LOSS train 0.06355241686105728 valid 0.018700785328595277
# Training vs. Validation Loss {'Training': 0.06355241686105728, 'Validation': 0.018700785328595277} 31
# Training vs. Validation accuracy {'Training': 0.9872424006462097, 'Validation': 0.9931740760803223} 31
# Epoch 31:
# Accuracy train:0.9862610697746277, val:0.9965870380401611
# LOSS train 0.061459752050443336 valid 0.011773631728525894
# Training vs. Validation Loss {'Training': 0.061459752050443336, 'Validation': 0.011773631728525894} 32
# Training vs. Validation accuracy {'Training': 0.9862610697746277, 'Validation': 0.9965870380401611} 32
# Epoch 32:
# Accuracy train:0.9803729057312012, val:0.9931740760803223
# LOSS train 0.07680239256184834 valid 0.019131917632572975
# Training vs. Validation Loss {'Training': 0.07680239256184834, 'Validation': 0.019131917632572975} 33
# Training vs. Validation accuracy {'Training': 0.9803729057312012, 'Validation': 0.9931740760803223} 33
# Epoch 33:
# Accuracy train:0.9803729057312012, val:0.9931740760803223
# LOSS train 0.07561240556578223 valid 0.023652707466681022
# Training vs. Validation Loss {'Training': 0.07561240556578223, 'Validation': 0.023652707466681022} 34
# Training vs. Validation accuracy {'Training': 0.9803729057312012, 'Validation': 0.9931740760803223} 34
# Epoch 34:
# Accuracy train:0.9882237315177917, val:0.9931740760803223
# LOSS train 0.06679807603359222 valid 0.019349752306879964
# Training vs. Validation Loss {'Training': 0.06679807603359222, 'Validation': 0.019349752306879964} 35
# Training vs. Validation accuracy {'Training': 0.9882237315177917, 'Validation': 0.9931740760803223} 35
# Epoch 35:
# Accuracy train:0.9872424006462097, val:0.9931740760803223
# LOSS train 0.06539879316607347 valid 0.020435844977328088
# Training vs. Validation Loss {'Training': 0.06539879316607347, 'Validation': 0.020435844977328088} 36
# Training vs. Validation accuracy {'Training': 0.9872424006462097, 'Validation': 0.9931740760803223} 36
# Epoch 36:
# Accuracy train:0.9882237315177917, val:0.9931740760803223
# LOSS train 0.049709742745527856 valid 0.01964291572464087
# Training vs. Validation Loss {'Training': 0.049709742745527856, 'Validation': 0.01964291572464087} 37
# Training vs. Validation accuracy {'Training': 0.9882237315177917, 'Validation': 0.9931740760803223} 37
# Epoch 37:
# Accuracy train:0.983316957950592, val:0.9931740760803223
# LOSS train 0.06442323423778781 valid 0.015509344142628834
# Training vs. Validation Loss {'Training': 0.06442323423778781, 'Validation': 0.015509344142628834} 38
# Training vs. Validation accuracy {'Training': 0.983316957950592, 'Validation': 0.9931740760803223} 38
# Epoch 38:
# Accuracy train:0.9872424006462097, val:0.9931740760803223
# LOSS train 0.05709650535852863 valid 0.02034061920979487
# Training vs. Validation Loss {'Training': 0.05709650535852863, 'Validation': 0.02034061920979487} 39
# Training vs. Validation accuracy {'Training': 0.9872424006462097, 'Validation': 0.9931740760803223} 39
# Epoch 39:
# Accuracy train:0.9862610697746277, val:0.9931740760803223
# LOSS train 0.04793546957751879 valid 0.013191599296987988
# Training vs. Validation Loss {'Training': 0.04793546957751879, 'Validation': 0.013191599296987988} 40
# Training vs. Validation accuracy {'Training': 0.9862610697746277, 'Validation': 0.9931740760803223} 40
# Epoch 40:
# Accuracy train:0.9842983484268188, val:0.9931740760803223
# LOSS train 0.06851281143295077 valid 0.015060724780293336
# Training vs. Validation Loss {'Training': 0.06851281143295077, 'Validation': 0.015060724780293336} 41
# Training vs. Validation accuracy {'Training': 0.9842983484268188, 'Validation': 0.9931740760803223} 41
# Epoch 41:
# Accuracy train:0.9901864528656006, val:0.9931740760803223
# LOSS train 0.04996892100629898 valid 0.014678833237364112
# Training vs. Validation Loss {'Training': 0.04996892100629898, 'Validation': 0.014678833237364112} 42
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9931740760803223} 42
# Epoch 42:
# Accuracy train:0.9911677837371826, val:0.9965870380401611
# LOSS train 0.0579058203058174 valid 0.010950741967462818
# Training vs. Validation Loss {'Training': 0.0579058203058174, 'Validation': 0.010950741967462818} 43
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9965870380401611} 43
# Epoch 43:
# Accuracy train:0.9872424006462097, val:0.9965870380401611
# LOSS train 0.06212250861482552 valid 0.013646599952456503
# Training vs. Validation Loss {'Training': 0.06212250861482552, 'Validation': 0.013646599952456503} 44
# Training vs. Validation accuracy {'Training': 0.9872424006462097, 'Validation': 0.9965870380401611} 44
# Epoch 44:
# Accuracy train:0.9852796792984009, val:0.9931740760803223
# LOSS train 0.05128024991315145 valid 0.012435287285673743
# Training vs. Validation Loss {'Training': 0.05128024991315145, 'Validation': 0.012435287285673743} 45
# Training vs. Validation accuracy {'Training': 0.9852796792984009, 'Validation': 0.9931740760803223} 45
# Epoch 45:
# Accuracy train:0.9882237315177917, val:0.9965870380401611
# LOSS train 0.03797324773712227 valid 0.009732684559518626
# Training vs. Validation Loss {'Training': 0.03797324773712227, 'Validation': 0.009732684559518626} 46
# Training vs. Validation accuracy {'Training': 0.9882237315177917, 'Validation': 0.9965870380401611} 46
# Epoch 46:
# Accuracy train:0.9892051219940186, val:0.9931740760803223
# LOSS train 0.0487989025333753 valid 0.011668816008750582
# Training vs. Validation Loss {'Training': 0.0487989025333753, 'Validation': 0.011668816008750582} 47
# Training vs. Validation accuracy {'Training': 0.9892051219940186, 'Validation': 0.9931740760803223} 47
# Epoch 47:
# Accuracy train:0.9892051219940186, val:0.9965870380401611
# LOSS train 0.049426894240940995 valid 0.009106835512890635
# Training vs. Validation Loss {'Training': 0.049426894240940995, 'Validation': 0.009106835512890635} 48
# Training vs. Validation accuracy {'Training': 0.9892051219940186, 'Validation': 0.9965870380401611} 48
# Epoch 48:
# Accuracy train:0.9852796792984009, val:0.9931740760803223
# LOSS train 0.06743529483747597 valid 0.010815867875256421
# Training vs. Validation Loss {'Training': 0.06743529483747597, 'Validation': 0.010815867875256421} 49
# Training vs. Validation accuracy {'Training': 0.9852796792984009, 'Validation': 0.9931740760803223} 49
# Epoch 49:
# Accuracy train:0.9921491742134094, val:0.9931740760803223
# LOSS train 0.055634211569737926 valid 0.014366602601512568
# Training vs. Validation Loss {'Training': 0.055634211569737926, 'Validation': 0.014366602601512568} 50
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9931740760803223} 50
# Epoch 50:
# Accuracy train:0.9882237315177917, val:0.9931740760803223
# LOSS train 0.041267189770363845 valid 0.013790354695326338
# Training vs. Validation Loss {'Training': 0.041267189770363845, 'Validation': 0.013790354695326338} 51
# Training vs. Validation accuracy {'Training': 0.9882237315177917, 'Validation': 0.9931740760803223} 51
# Epoch 51:
# Accuracy train:0.9882237315177917, val:0.9931740760803223
# LOSS train 0.04012404047310925 valid 0.013601758822611979
# Training vs. Validation Loss {'Training': 0.04012404047310925, 'Validation': 0.013601758822611979} 52
# Training vs. Validation accuracy {'Training': 0.9882237315177917, 'Validation': 0.9931740760803223} 52
# Epoch 52:
# Accuracy train:0.9921491742134094, val:0.9965870380401611
# LOSS train 0.051456437464087054 valid 0.011529798680082118
# Training vs. Validation Loss {'Training': 0.051456437464087054, 'Validation': 0.011529798680082118} 53
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9965870380401611} 53
# Epoch 53:
# Accuracy train:0.9892051219940186, val:0.9965870380401611
# LOSS train 0.05572534667757841 valid 0.012487096839625641
# Training vs. Validation Loss {'Training': 0.05572534667757841, 'Validation': 0.012487096839625641} 54
# Training vs. Validation accuracy {'Training': 0.9892051219940186, 'Validation': 0.9965870380401611} 54
# Epoch 54:
# Accuracy train:0.9911677837371826, val:0.9931740760803223
# LOSS train 0.041854824494713776 valid 0.008968777048115347
# Training vs. Validation Loss {'Training': 0.041854824494713776, 'Validation': 0.008968777048115347} 55
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9931740760803223} 55
# Epoch 55:
# Accuracy train:0.9901864528656006, val:0.9965870380401611
# LOSS train 0.045751912107404605 valid 0.015793020179747447
# Training vs. Validation Loss {'Training': 0.045751912107404605, 'Validation': 0.015793020179747447} 56
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9965870380401611} 56
# Epoch 56:
# Accuracy train:0.9872424006462097, val:0.9965870380401611
# LOSS train 0.041879474865989044 valid 0.014455199350171219
# Training vs. Validation Loss {'Training': 0.041879474865989044, 'Validation': 0.014455199350171219} 57
# Training vs. Validation accuracy {'Training': 0.9872424006462097, 'Validation': 0.9965870380401611} 57
# Epoch 57:
# Accuracy train:0.9901864528656006, val:0.9931740760803223
# LOSS train 0.035387604318272606 valid 0.008578909906039675
# Training vs. Validation Loss {'Training': 0.035387604318272606, 'Validation': 0.008578909906039675} 58
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9931740760803223} 58
# Epoch 58:
# Accuracy train:0.9882237315177917, val:0.9965870380401611
# LOSS train 0.04282929562032223 valid 0.009827089224927477
# Training vs. Validation Loss {'Training': 0.04282929562032223, 'Validation': 0.009827089224927477} 59
# Training vs. Validation accuracy {'Training': 0.9882237315177917, 'Validation': 0.9965870380401611} 59
# Epoch 59:
# Accuracy train:0.9901864528656006, val:0.9931740760803223
# LOSS train 0.03248945012903558 valid 0.01082253870238977
# Training vs. Validation Loss {'Training': 0.03248945012903558, 'Validation': 0.01082253870238977} 60
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9931740760803223} 60
# Epoch 60:
# Accuracy train:0.9950932264328003, val:0.9965870380401611
# LOSS train 0.0236808618870922 valid 0.012987740305106854
# Training vs. Validation Loss {'Training': 0.0236808618870922, 'Validation': 0.012987740305106854} 61
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9965870380401611} 61
# Epoch 61:
# Accuracy train:0.9872424006462097, val:0.9965870380401611
# LOSS train 0.031608881428837776 valid 0.012094861671357648
# Training vs. Validation Loss {'Training': 0.031608881428837776, 'Validation': 0.012094861671357648} 62
# Training vs. Validation accuracy {'Training': 0.9872424006462097, 'Validation': 0.9965870380401611} 62
# Epoch 62:
# Accuracy train:0.9892051219940186, val:0.9931740760803223
# LOSS train 0.032668975952009745 valid 0.009600680168659892
# Training vs. Validation Loss {'Training': 0.032668975952009745, 'Validation': 0.009600680168659892} 63
# Training vs. Validation accuracy {'Training': 0.9892051219940186, 'Validation': 0.9931740760803223} 63
# Epoch 63:
# Accuracy train:0.9941118955612183, val:0.9965870380401611
# LOSS train 0.03355785099288019 valid 0.00902753881746321
# Training vs. Validation Loss {'Training': 0.03355785099288019, 'Validation': 0.00902753881746321} 64
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9965870380401611} 64
# Epoch 64:
# Accuracy train:0.9911677837371826, val:0.9931740760803223
# LOSS train 0.04649056596323275 valid 0.0065012193733006525
# Training vs. Validation Loss {'Training': 0.04649056596323275, 'Validation': 0.0065012193733006525} 65
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9931740760803223} 65
# Epoch 65:
# Accuracy train:0.9921491742134094, val:0.9931740760803223
# LOSS train 0.032822550856508315 valid 0.01002616390996991
# Training vs. Validation Loss {'Training': 0.032822550856508315, 'Validation': 0.01002616390996991} 66
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9931740760803223} 66
# Epoch 66:
# Accuracy train:0.9911677837371826, val:0.9931740760803223
# LOSS train 0.033132106047840074 valid 0.016421481988800224
# Training vs. Validation Loss {'Training': 0.033132106047840074, 'Validation': 0.016421481988800224} 67
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9931740760803223} 67
# Epoch 67:
# Accuracy train:0.9892051219940186, val:0.9931740760803223
# LOSS train 0.03781462462547307 valid 0.015285453918750136
# Training vs. Validation Loss {'Training': 0.03781462462547307, 'Validation': 0.015285453918750136} 68
# Training vs. Validation accuracy {'Training': 0.9892051219940186, 'Validation': 0.9931740760803223} 68
# Epoch 68:
# Accuracy train:0.9931305050849915, val:0.9931740760803223
# LOSS train 0.023229512735269964 valid 0.012476667000555608
# Training vs. Validation Loss {'Training': 0.023229512735269964, 'Validation': 0.012476667000555608} 69
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9931740760803223} 69
# Epoch 69:
# Accuracy train:0.9911677837371826, val:0.9897611141204834
# LOSS train 0.028008054977712724 valid 0.013427321503513667
# Training vs. Validation Loss {'Training': 0.028008054977712724, 'Validation': 0.013427321503513667} 70
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9897611141204834} 70
# Epoch 70:
# Accuracy train:0.9941118955612183, val:0.9931740760803223
# LOSS train 0.028816060001890246 valid 0.009007918515635538
# Training vs. Validation Loss {'Training': 0.028816060001890246, 'Validation': 0.009007918515635538} 71
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9931740760803223} 71
# Epoch 71:
# Accuracy train:0.9931305050849915, val:0.9931740760803223
# LOSS train 0.03214972238772763 valid 0.015533017484206843
# Training vs. Validation Loss {'Training': 0.03214972238772763, 'Validation': 0.015533017484206843} 72
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9931740760803223} 72
# Epoch 72:
# Accuracy train:0.9921491742134094, val:0.9931740760803223
# LOSS train 0.02887544256205169 valid 0.012129811294168272
# Training vs. Validation Loss {'Training': 0.02887544256205169, 'Validation': 0.012129811294168272} 73
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9931740760803223} 73
# Epoch 73:
# Accuracy train:0.9911677837371826, val:0.9931740760803223
# LOSS train 0.033294255567642934 valid 0.015860446336773748
# Training vs. Validation Loss {'Training': 0.033294255567642934, 'Validation': 0.015860446336773748} 74
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9931740760803223} 74
# Epoch 74:
# Accuracy train:0.9931305050849915, val:0.9931740760803223
# LOSS train 0.03499545675003901 valid 0.01582564313093826
# Training vs. Validation Loss {'Training': 0.03499545675003901, 'Validation': 0.01582564313093826} 75
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9931740760803223} 75
# Epoch 75:
# Accuracy train:0.9911677837371826, val:0.9931740760803223
# LOSS train 0.04807564822168878 valid 0.016464983318049537
# Training vs. Validation Loss {'Training': 0.04807564822168878, 'Validation': 0.016464983318049537} 76
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9931740760803223} 76
# Epoch 76:
# Accuracy train:0.9892051219940186, val:0.9931740760803223
# LOSS train 0.03883964767178091 valid 0.013796015394291317
# Training vs. Validation Loss {'Training': 0.03883964767178091, 'Validation': 0.013796015394291317} 77
# Training vs. Validation accuracy {'Training': 0.9892051219940186, 'Validation': 0.9931740760803223} 77
# Epoch 77:
# Accuracy train:0.9921491742134094, val:0.9931740760803223
# LOSS train 0.04576709253104547 valid 0.014037593036164253
# Training vs. Validation Loss {'Training': 0.04576709253104547, 'Validation': 0.014037593036164253} 78
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9931740760803223} 78
# Epoch 78:
# Accuracy train:0.9921491742134094, val:0.9931740760803223
# LOSS train 0.039520426107069045 valid 0.014462385833212466
# Training vs. Validation Loss {'Training': 0.039520426107069045, 'Validation': 0.014462385833212466} 79
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9931740760803223} 79
# Epoch 79:
# Accuracy train:0.9901864528656006, val:0.9931740760803223
# LOSS train 0.04051778512971046 valid 0.014559924651318093
# Training vs. Validation Loss {'Training': 0.04051778512971046, 'Validation': 0.014559924651318093} 80
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9931740760803223} 80
# Epoch 80:
# Accuracy train:0.9921491742134094, val:0.9931740760803223
# LOSS train 0.0330205614960645 valid 0.015425943129154499
# Training vs. Validation Loss {'Training': 0.0330205614960645, 'Validation': 0.015425943129154499} 81
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9931740760803223} 81
# Epoch 81:
# Accuracy train:0.9911677837371826, val:0.9931740760803223
# LOSS train 0.03252635446663659 valid 0.014839387812874824
# Training vs. Validation Loss {'Training': 0.03252635446663659, 'Validation': 0.014839387812874824} 82
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9931740760803223} 82
# Epoch 82:
# Accuracy train:0.9921491742134094, val:0.9931740760803223
# LOSS train 0.05048128435961329 valid 0.013577457371563165
# Training vs. Validation Loss {'Training': 0.05048128435961329, 'Validation': 0.013577457371563165} 83
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9931740760803223} 83
# Epoch 83:
# Accuracy train:0.9911677837371826, val:0.9931740760803223
# LOSS train 0.04138254275984274 valid 0.0121401230489937
# Training vs. Validation Loss {'Training': 0.04138254275984274, 'Validation': 0.0121401230489937} 84
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9931740760803223} 84
# Epoch 84:
# Accuracy train:0.9931305050849915, val:0.9931740760803223
# LOSS train 0.02265362215649265 valid 0.012711855805870679
# Training vs. Validation Loss {'Training': 0.02265362215649265, 'Validation': 0.012711855805870679} 85
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9931740760803223} 85
# Epoch 85:
# Accuracy train:0.9950932264328003, val:0.9931740760803223
# LOSS train 0.018646460169783004 valid 0.013936092059793737
# Training vs. Validation Loss {'Training': 0.018646460169783004, 'Validation': 0.013936092059793737} 86
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9931740760803223} 86
# Epoch 86:
# Accuracy train:0.9960745573043823, val:0.9931740760803223
# LOSS train 0.028093011252796993 valid 0.01625525172047067
# Training vs. Validation Loss {'Training': 0.028093011252796993, 'Validation': 0.01625525172047067} 87
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9931740760803223} 87
# Epoch 87:
# Accuracy train:0.9852796792984009, val:0.9931740760803223
# LOSS train 0.021940347702743914 valid 0.01814450434335413
# Training vs. Validation Loss {'Training': 0.021940347702743914, 'Validation': 0.01814450434335413} 88
# Training vs. Validation accuracy {'Training': 0.9852796792984009, 'Validation': 0.9931740760803223} 88
# Epoch 88:
# Accuracy train:0.9911677837371826, val:0.9931740760803223
# LOSS train 0.023747269735814862 valid 0.0171000211161072
# Training vs. Validation Loss {'Training': 0.023747269735814862, 'Validation': 0.0171000211161072} 89
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9931740760803223} 89
# Epoch 89:
# Accuracy train:0.9960745573043823, val:0.9931740760803223
# LOSS train 0.03169226955371694 valid 0.015843362436119907
# Training vs. Validation Loss {'Training': 0.03169226955371694, 'Validation': 0.015843362436119907} 90
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9931740760803223} 90
# Epoch 90:
# Accuracy train:0.9941118955612183, val:0.9931740760803223
# LOSS train 0.016020879131526902 valid 0.016526429111953195
# Training vs. Validation Loss {'Training': 0.016020879131526902, 'Validation': 0.016526429111953195} 91
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9931740760803223} 91
# Epoch 91:
# Accuracy train:0.9931305050849915, val:0.9965870380401611
# LOSS train 0.015788345011130262 valid 0.016849843864084352
# Training vs. Validation Loss {'Training': 0.015788345011130262, 'Validation': 0.016849843864084352} 92
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9965870380401611} 92
# Epoch 92:
# Accuracy train:0.9950932264328003, val:0.9931740760803223
# LOSS train 0.014729494560294999 valid 0.014418400975614531
# Training vs. Validation Loss {'Training': 0.014729494560294999, 'Validation': 0.014418400975614531} 93
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9931740760803223} 93
# Epoch 93:
# Accuracy train:0.9941118955612183, val:0.9931740760803223
# LOSS train 0.026853812974877656 valid 0.016944501097403492
# Training vs. Validation Loss {'Training': 0.026853812974877656, 'Validation': 0.016944501097403492} 94
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9931740760803223} 94
# Epoch 94:
# Accuracy train:0.9911677837371826, val:0.9931740760803223
# LOSS train 0.03412715278906175 valid 0.016351897071065952
# Training vs. Validation Loss {'Training': 0.03412715278906175, 'Validation': 0.016351897071065952} 95
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9931740760803223} 95
# Epoch 95:
# Accuracy train:0.9921491742134094, val:0.9931740760803223
# LOSS train 0.029108616646576244 valid 0.017143928611706844
# Training vs. Validation Loss {'Training': 0.029108616646576244, 'Validation': 0.017143928611706844} 96
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9931740760803223} 96
# Epoch 96:
# Accuracy train:0.9941118955612183, val:0.9931740760803223
# LOSS train 0.01578739004281278 valid 0.014528305250526804
# Training vs. Validation Loss {'Training': 0.01578739004281278, 'Validation': 0.014528305250526804} 97
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9931740760803223} 97
# Epoch 97:
# Accuracy train:0.9941118955612183, val:0.9931740760803223
# LOSS train 0.024194186633954253 valid 0.013906109788422327
# Training vs. Validation Loss {'Training': 0.024194186633954253, 'Validation': 0.013906109788422327} 98
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9931740760803223} 98
# Epoch 98:
# Accuracy train:0.9921491742134094, val:0.9931740760803223
# LOSS train 0.030772127918540858 valid 0.01992541575816631
# Training vs. Validation Loss {'Training': 0.030772127918540858, 'Validation': 0.01992541575816631} 99
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9931740760803223} 99
# Epoch 99:
# Accuracy train:0.9941118955612183, val:0.9931740760803223
# LOSS train 0.03745209517924545 valid 0.01904375376157456
# Training vs. Validation Loss {'Training': 0.03745209517924545, 'Validation': 0.01904375376157456} 100
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9931740760803223} 100
# Epoch 100:
# Accuracy train:0.9921491742134094, val:0.9931740760803223
# LOSS train 0.028352465961898606 valid 0.018759223271331393
# Training vs. Validation Loss {'Training': 0.028352465961898606, 'Validation': 0.018759223271331393} 101
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9931740760803223} 101
# Epoch 101:
# Accuracy train:0.9950932264328003, val:0.9931740760803223
# LOSS train 0.01567361892039816 valid 0.016305618469914407
# Training vs. Validation Loss {'Training': 0.01567361892039816, 'Validation': 0.016305618469914407} 102
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9931740760803223} 102
# Epoch 102:
# Accuracy train:0.9941118955612183, val:0.9931740760803223
# LOSS train 0.02379758138424502 valid 0.01669291851453636
# Training vs. Validation Loss {'Training': 0.02379758138424502, 'Validation': 0.01669291851453636} 103
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9931740760803223} 103
# Epoch 103:
# Accuracy train:0.9970559477806091, val:0.9931740760803223
# LOSS train 0.02041138696949929 valid 0.01736145186930571
# Training vs. Validation Loss {'Training': 0.02041138696949929, 'Validation': 0.01736145186930571} 104
# Training vs. Validation accuracy {'Training': 0.9970559477806091, 'Validation': 0.9931740760803223} 104
# Epoch 104:
# Accuracy train:0.9960745573043823, val:0.9931740760803223
# LOSS train 0.014669834268995775 valid 0.017223021902414832
# Training vs. Validation Loss {'Training': 0.014669834268995775, 'Validation': 0.017223021902414832} 105
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9931740760803223} 105
# Epoch 105:
# Accuracy train:0.9931305050849915, val:0.9897611141204834
# LOSS train 0.02128785846826549 valid 0.02349476885420169
# Training vs. Validation Loss {'Training': 0.02128785846826549, 'Validation': 0.02349476885420169} 106
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9897611141204834} 106
# Epoch 106:
# Accuracy train:0.9931305050849915, val:0.9931740760803223
# LOSS train 0.02297850195855762 valid 0.02001991618703869
# Training vs. Validation Loss {'Training': 0.02297850195855762, 'Validation': 0.02001991618703869} 107
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9931740760803223} 107
# Epoch 107:
# Accuracy train:0.9950932264328003, val:0.9931740760803223
# LOSS train 0.012635051362359753 valid 0.018462841190853396
# Training vs. Validation Loss {'Training': 0.012635051362359753, 'Validation': 0.018462841190853396} 108
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9931740760803223} 108
# Epoch 108:
# Accuracy train:0.9941118955612183, val:0.9931740760803223
# LOSS train 0.028850628398896124 valid 0.01845977768323337
# Training vs. Validation Loss {'Training': 0.028850628398896124, 'Validation': 0.01845977768323337} 109
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9931740760803223} 109
# Epoch 109:
# Accuracy train:0.9960745573043823, val:0.9931740760803223
# LOSS train 0.01776869682586179 valid 0.01704768374584849
# Training vs. Validation Loss {'Training': 0.01776869682586179, 'Validation': 0.01704768374584849} 110
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9931740760803223} 110
# Epoch 110:
# Accuracy train:0.9911677837371826, val:0.9931740760803223
# LOSS train 0.019094469404080883 valid 0.018049003178058836
# Training vs. Validation Loss {'Training': 0.019094469404080883, 'Validation': 0.018049003178058836} 111
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9931740760803223} 111
# Epoch 111:
# Accuracy train:0.9931305050849915, val:0.9931740760803223
# LOSS train 0.013505569408432795 valid 0.018257030938949963
# Training vs. Validation Loss {'Training': 0.013505569408432795, 'Validation': 0.018257030938949963} 112
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9931740760803223} 112
# Epoch 112:
# Accuracy train:0.9911677837371826, val:0.9931740760803223
# LOSS train 0.016124136871300064 valid 0.019242675412328936
# Training vs. Validation Loss {'Training': 0.016124136871300064, 'Validation': 0.019242675412328936} 113
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9931740760803223} 113
# Epoch 113:
# Accuracy train:0.9941118955612183, val:0.9931740760803223
# LOSS train 0.019268812701249353 valid 0.019620416711764694
# Training vs. Validation Loss {'Training': 0.019268812701249353, 'Validation': 0.019620416711764694} 114
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9931740760803223} 114
# Epoch 114:
# Accuracy train:0.9950932264328003, val:0.9931740760803223
# LOSS train 0.01812302955211355 valid 0.017350167848330027
# Training vs. Validation Loss {'Training': 0.01812302955211355, 'Validation': 0.017350167848330027} 115
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9931740760803223} 115
# Epoch 115:
# Accuracy train:0.9950932264328003, val:0.9931740760803223
# LOSS train 0.018560649307731252 valid 0.02000126481546734
# Training vs. Validation Loss {'Training': 0.018560649307731252, 'Validation': 0.02000126481546734} 116
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9931740760803223} 116
# Epoch 116:
# Accuracy train:0.9960745573043823, val:0.9931740760803223
# LOSS train 0.024719123939016405 valid 0.01831080058320822
# Training vs. Validation Loss {'Training': 0.024719123939016405, 'Validation': 0.01831080058320822} 117
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9931740760803223} 117
# Epoch 117:
# Accuracy train:0.9950932264328003, val:0.9897611141204834
# LOSS train 0.02032905168240317 valid 0.021406158000388587
# Training vs. Validation Loss {'Training': 0.02032905168240317, 'Validation': 0.021406158000388587} 118
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9897611141204834} 118
# Epoch 118:
# Accuracy train:0.9921491742134094, val:0.9931740760803223
# LOSS train 0.02735100911769013 valid 0.02118637419051576
# Training vs. Validation Loss {'Training': 0.02735100911769013, 'Validation': 0.02118637419051576} 119
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9931740760803223} 119
# Epoch 119:
# Accuracy train:0.9960745573043823, val:0.9931740760803223
# LOSS train 0.02109229951747693 valid 0.02074899675570426
# Training vs. Validation Loss {'Training': 0.02109229951747693, 'Validation': 0.02074899675570426} 120
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9931740760803223} 120
# Epoch 120:
# Accuracy train:0.9950932264328003, val:0.9897611141204834
# LOSS train 0.016969139374291096 valid 0.025901059365916506
# Training vs. Validation Loss {'Training': 0.016969139374291096, 'Validation': 0.025901059365916506} 121
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9897611141204834} 121
# Epoch 121:
# Accuracy train:0.9950932264328003, val:0.9931740760803223
# LOSS train 0.016705079812359493 valid 0.02285397704491743
# Training vs. Validation Loss {'Training': 0.016705079812359493, 'Validation': 0.02285397704491743} 122
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9931740760803223} 122
# Epoch 122:
# Accuracy train:0.9960745573043823, val:0.9931740760803223
# LOSS train 0.01826776092639193 valid 0.0232913538388478
# Training vs. Validation Loss {'Training': 0.01826776092639193, 'Validation': 0.0232913538388478} 123
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9931740760803223} 123
# stopping at epoch 122, minimum: 0.0065012193733006525
# tensor(0.9932)

# %%
try:
  data = pd.read_csv(train_path)
  print(data.head())
except pd.errors.EmptyDataError:
  print("The file is empty or not properly formatted.")
# Out:
#    0  0.7041656374931335  0.9331732392311096  2.3629421264104167e-07  \
# 0  0            0.704025            0.935561            2.270204e-07
# 1  0            0.704607            0.938062            2.319889e-07
# 2  0            0.702362            0.943863            2.205633e-07
# 3  0            0.697163            0.949320            2.126994e-07
# 4  0            0.688938            0.950202            2.060856e-07
#
#    0.6453855037689209  0.8751612901687622  -0.015095236711204052  \
# 0            0.645960            0.877507              -0.014439
# 1            0.646883            0.881024              -0.015095
# 2            0.643890            0.886386              -0.013961
# 3            0.640218            0.891222              -0.013555
# 4            0.632643            0.888725              -0.012159
#
#    0.6154038906097412  0.7791009545326233  -0.01818155124783516  ...  \
# 0            0.616437            0.780532             -0.017399  ...
# 1            0.616943            0.783663             -0.018365  ...
# 2            0.614006            0.788738             -0.016410  ...
# 3            0.609613            0.791224             -0.015798  ...
# 4            0.601292            0.791456             -0.014669  ...
#
#    -0.008226240985095501  0.738134503364563  0.6249264478683472  \
# 0              -0.009820           0.739345            0.626345
# 1              -0.009688           0.739604            0.629359
# 2              -0.009088           0.738516            0.630970
# 3              -0.010292           0.733917            0.634837
# 4              -0.012476           0.725455            0.633064
#
#    -0.012530106119811535  0.7318564057350159  0.5787695050239563  \
# 0              -0.014831            0.733036            0.580175
# 1              -0.013962            0.733451            0.582893
# 2              -0.014157            0.732393            0.584941
# 3              -0.016298            0.727795            0.587993
# 4              -0.017650            0.720313            0.587245
#
#    -0.01326496060937643  0.7236258387565613  0.5379498600959778  \
# 0             -0.015863            0.724473            0.539224
# 1             -0.014675            0.725434            0.541968
# 2             -0.015349            0.723804            0.542737
# 3             -0.018262            0.718961            0.545056
# 4             -0.018292            0.712449            0.546029
#
#    -0.014287249185144901
# 0              -0.017028
# 1              -0.015724
# 2              -0.016781
# 3              -0.020209
# 4              -0.019218
#
# [5 rows x 64 columns]

# %%
list_label = label_dict_from_config_file("hand_gesture.yaml")
DATA_FOLDER_PATH="./data/"
testset = CustomImageDataset(os.path.join(DATA_FOLDER_PATH,"landmark_test.csv"))

# Test DataLoader instantiation
test_loader = torch.utils.data.DataLoader(testset, batch_size =20, shuffle = False)

network = NeuralNetwork()
network.load_state_dict(torch.load(best_model_path, weights_only=False))

network.eval()
acc_test = Accuracy(num_classes=len(list_label), task='MULTICLASS')
for i, test_data in enumerate(test_loader):
    test_input, test_label = test_data

    preds = network(test_input)
    acc_test.update(preds, test_label)

print(network.__class__.__name__)
print(f"Accuracy of model:{acc_test.compute().item()}")
print("========================================================================")
# Out:
# NeuralNetwork
# Accuracy of model:0.9724409580230713
# ========================================================================
